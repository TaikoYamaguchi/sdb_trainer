# %%
import pandas as pd
import json
from pandas import json_normalize

# 1. CSV 파일 불러오기
df = pd.read_csv('history.csv')

# 2. JSON 데이터 파싱 및 리스트로 변환
def parse_json_column(json_str):
    try:
        return json.loads(json_str)
    except json.JSONDecodeError:
        return []

# 특정 칼럼이 'json_column'이라고 가정
df['exercises'] = df['exercises'].apply(parse_json_column)

# 3. 리스트를 행으로 추가
# JSON 리스트가 담긴 칼럼을 분리
expanded_df = df.explode('exercises')


# 4. 결과를 새로운 CSV 파일로 저장
expanded_df.to_csv('expanded_file.csv', index=True,encoding='utf-8-sig')

# 결과 확인
print(expanded_df)
# Out:
#         id                           user_email  \
# 0       27                                  jgf
# 1       38                     gkwls1@naver.com
# 2       40                      dragk8@nate.com
# 2       40                      dragk8@nate.com
# 3       41                   twin1235@gmail.com
# ...    ...                                  ...
# 1660  2066                  tayoun011@naver.com
# 1661  2067                  vkvkvk369@naver.com
# 1662  2068  bhctxz5g4y@privaterelay.appleid.com
# 1663  2069                 jjbkjy1013@gmail.com
# 1664  2070                   cksnrlrl@naver.com
#
#                                               exercises  \
# 0     {'date': '2022-07-10', 'goal': 48.6, 'name': '...
# 1     {'date': '2022-07-18', 'goal': 46.800000000000...
# 2     {'date': '2022-07-20', 'goal': 200.0, 'name': ...
# 2     {'date': '2022-07-20', 'goal': 216.0, 'name': ...
# 3     {'date': '2022-07-21', 'goal': 110.00000000000...
# ...                                                 ...
# 1660  [{"name":"러닝","sets":[{"index":72.0,"weight":1...
# 1661  [{"name":"푸쉬업","sets":[{"index":46.0,"weight":...
# 1662  [{"name":"바벨 스쿼트","sets":[{"index":0.0,"weight...
# 1663  [{"name":"로프 트라이셉스 푸쉬다운","sets":[{"index":0.0,...
# 1664  [{"name":"로우 케이블 크로스 오버","sets":[{"index":33.5...
#
#                             date  new_record  workout_time  \
# 0     2022-07-10 19:28:45.978806         120             4
# 1     2022-07-18 12:14:22.529347         120             7
# 2     2022-07-20 21:04:52.714613         120            31
# 2     2022-07-20 21:04:52.714613         120            31
# 3     2022-07-21 12:14:33.506616         120             0
# ...                          ...         ...           ...
# 1660  2024-07-12 18:59:47.015521           0          6630
# 1661  2024-07-13 12:11:19.222535           0          3504
# 1662  2024-07-13 16:52:16.062788           4          2494
# 1663  2024-07-13 23:59:31.420032           0          3322
# 1664   2024-07-14 14:31:09.64439           6          4958
#
#                                          like dislike image          comment  \
# 0                                       {jgf}      {}    {}              NaN
# 1                                          {}      {}    {}              NaN
# 2        {dragk8@nate.com,cksnrlrl@naver.com}      {}    {}         오늘컨디션 최고
# 2        {dragk8@nate.com,cksnrlrl@naver.com}      {}    {}         오늘컨디션 최고
# 3                                          {}      {}    {}              NaN
# ...                                       ...     ...   ...              ...
# 1660  {twin1235@gmail.com,cksnrlrl@naver.com}      {}    {}  벤치프레스가 그나마 좀 된다
# 1661                     {cksnrlrl@naver.com}      {}    {}              NaN
# 1662   {cksdnr1@gmail.com,cksnrlrl@naver.com}      {}    {}              NaN
# 1663                     {cksnrlrl@naver.com}      {}    {}              NaN
# 1664                                       {}      {}    {}         후 가슴어깨삼두
#
#      nickname  comment_length               ip  isVisible
# 0         sgh               0  182.210.227.110       True
# 1      lp2342               0    211.36.142.45      False
# 2         오크찬               2    106.101.64.80       True
# 2         오크찬               2    106.101.64.80       True
# 3         aaa               0  106.101.193.193       True
# ...       ...             ...              ...        ...
# 1660     하댕사랑               0  211.234.188.221       True
# 1661    밀리언치즈               0  211.209.156.225       True
# 1662     근자헬스               0   211.235.98.213       True
# 1663   골격근량40               0      39.7.24.179       True
# 1664  IronMan               0     106.101.3.29       True
#
# [2227 rows x 14 columns]

# %%
import pandas as pd
import json
from pandas import json_normalize

# 1. CSV 파일 불러오기
df = pd.read_csv('history.csv')

# 2. JSON 데이터 파싱 및 리스트로 변환
def parse_json_column(json_str):
    try:
        json_str = json_str.strip('"').replace('\\', '')
        return json.loads(json_str)
    except json.JSONDecodeError:
        return []

# 특정 칼럼이 'json_column'이라고 가정
df = df.drop(columns='comment')
df['exercises'] = df['exercises'].apply(parse_json_column)

# 3. 리스트를 행으로 추가
# JSON 리스트가 담긴 칼럼을 분리
expanded_df = df.explode('exercises')

expanded_df = expanded_df.reset_index(drop=True)


json_normalized_df = json_normalize(expanded_df['exercises'])
json_normalized_df = json_normalized_df.drop(columns='date')


expanded_df = pd.concat([expanded_df.drop(columns='exercises'), json_normalized_df], axis=1)

expanded_df = expanded_df.reset_index(drop=True)

expanded_df = expanded_df.explode('sets')

expanded_df = expanded_df.reset_index(drop=True)

json_normalized_df = json_normalize(expanded_df['sets'])
expanded_df = pd.concat([expanded_df.drop(columns='sets'), json_normalized_df], axis=1)

# 4. 결과를 새로운 CSV 파일로 저장
expanded_df.to_csv('expanded_file3.csv', index=False,encoding='utf-8-sig')

# 결과 확인
print(expanded_df)
# Out:
#          id          user_email                        date  new_record  \
# 0        27                 jgf  2022-07-10 19:28:45.978806         120
# 1        38    gkwls1@naver.com  2022-07-18 12:14:22.529347         120
# 2        38    gkwls1@naver.com  2022-07-18 12:14:22.529347         120
# 3        40     dragk8@nate.com  2022-07-20 21:04:52.714613         120
# 4        40     dragk8@nate.com  2022-07-20 21:04:52.714613         120
# ...     ...                 ...                         ...         ...
# 27925  2070  cksnrlrl@naver.com   2024-07-14 14:31:09.64439           6
# 27926  2070  cksnrlrl@naver.com   2024-07-14 14:31:09.64439           6
# 27927  2070  cksnrlrl@naver.com   2024-07-14 14:31:09.64439           6
# 27928  2070  cksnrlrl@naver.com   2024-07-14 14:31:09.64439           6
# 27929  2070  cksnrlrl@naver.com   2024-07-14 14:31:09.64439           6
#
#        workout_time                                  like dislike image  \
# 0                 4                                 {jgf}      {}    {}
# 1                 7                                    {}      {}    {}
# 2                 7                                    {}      {}    {}
# 3                31  {dragk8@nate.com,cksnrlrl@naver.com}      {}    {}
# 4                31  {dragk8@nate.com,cksnrlrl@naver.com}      {}    {}
# ...             ...                                   ...     ...   ...
# 27925          4958                                    {}      {}    {}
# 27926          4958                                    {}      {}    {}
# 27927          4958                                    {}      {}    {}
# 27928          4958                                    {}      {}    {}
# 27929          4958                                    {}      {}    {}
#
#       nickname  comment_length               ip  isVisible   goal  \
# 0          sgh               0  182.210.227.110       True   48.6
# 1       lp2342               0    211.36.142.45      False   46.8
# 2       lp2342               0    211.36.142.45      False   46.8
# 3          오크찬               2    106.101.64.80       True  200.0
# 4          오크찬               2    106.101.64.80       True  200.0
# ...        ...             ...              ...        ...    ...
# 27925  IronMan               0     106.101.3.29       True    0.0
# 27926  IronMan               0     106.101.3.29       True    0.0
# 27927  IronMan               0     106.101.3.29       True    0.0
# 27928  IronMan               0     106.101.3.29       True    0.0
# 27929  IronMan               0     106.101.3.29       True    0.0
#
#                     name                                               sets  \
# 0                 바벨 스쿼트  {'reps': 1, 'index': 0.0, 'weight': 50.0, 'isc...
# 1                 바벨 스쿼트  {'reps': 1, 'index': 0.0, 'weight': 180.0, 'is...
# 2                 바벨 스쿼트  {'reps': 1, 'index': 1.0, 'weight': 170.0, 'is...
# 3                 바벨 스쿼트  {'reps': 5, 'index': 0.0, 'weight': 120.0, 'is...
# 4                 바벨 스쿼트  {'reps': 4, 'index': 1.0, 'weight': 140.0, 'is...
# ...                  ...                                                ...
# 27925         스탠딩 덤벨 플라이  {'index': 40.0, 'weight': 6.0, 'reps': 15, 'is...
# 27926  라잉 EZ바 트라이셉스 익스텐션  {'index': 52.6, 'weight': 20.0, 'reps': 20, 'i...
# 27927  라잉 EZ바 트라이셉스 익스텐션  {'index': 65.7, 'weight': 25.0, 'reps': 20, 'i...
# 27928  라잉 EZ바 트라이셉스 익스텐션  {'index': 49.5, 'weight': 25.0, 'reps': 25, 'i...
# 27929  라잉 EZ바 트라이셉스 익스텐션  {'index': 49.5, 'weight': 25.0, 'reps': 20, 'i...
#
#             onerm isCardio
# 0       50.000000      NaN
# 1      180.000000      NaN
# 2      180.000000      NaN
# 3      204.000000      NaN
# 4      204.000000      NaN
# ...           ...      ...
# 27925   10.400000    False
# 27926   45.833333    False
# 27927   45.833333    False
# 27928   45.833333    False
# 27929   45.833333    False
#
# [27930 rows x 17 columns]
